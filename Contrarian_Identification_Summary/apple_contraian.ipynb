# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load Excel file and read all sheets
file_path = "Apple_with_sentiment.xlsx"  # Update as needed
xls = pd.ExcelFile(file_path)
sheet_names = xls.sheet_names

# Step 2: Combine sheets into a single DataFrame, labeling by quarter
combined_df = pd.concat(
    [xls.parse(sheet).assign(Quarter=sheet) for sheet in sheet_names],
    ignore_index=True
)

# Step 3: Define true EPS sentiment direction for each quarter
eps_sentiment = {
    'Q2 2025': 'Positive',   # EPS Surprise: 1.23%
    'Q1 2025': 'Positive',   # EPS Surprise: 1.69%
    'Q4 2024': 'Positive',   # EPS Surprise: 2.5%
    'Q3 2024': 'Positive'    # EPS Surprise: 3.7%
}

# Step 4: Tag articles with sentiment alignment
combined_df['Sentiment'] = combined_df['Sentiment'].fillna('Neutral')
combined_df['EPS_Sentiment'] = combined_df['Quarter'].map(eps_sentiment)
combined_df['Sentiment_Alignment'] = combined_df['Sentiment'] == combined_df['EPS_Sentiment']

# Step 5: Filter only correctly aligned articles
correct_df = combined_df[combined_df['Sentiment_Alignment']][
    ['Quarter', 'Headline', 'Authors', 'Sentiment', 'EPS_Sentiment']
]

print("Articles with Correct Sentiment Matching EPS Surprise:\n")
print(correct_df.to_string(index=False))

# Step 6: Compute percentage of correctly aligned sentiment per quarter
correct_sentiment_pct = (
    combined_df.groupby('Quarter')['Sentiment_Alignment']
    .mean()
    .reset_index()
    .rename(columns={'Sentiment_Alignment': 'Correct Sentiment %'})
)
correct_sentiment_pct['Correct Sentiment %'] *= 100

# Step 7: Ensure all quarters in EPS list are present
for q in eps_sentiment:
    if q not in correct_sentiment_pct['Quarter'].values:
        correct_sentiment_pct = pd.concat([
            correct_sentiment_pct,
            pd.DataFrame({'Quarter': [q], 'Correct Sentiment %': [0]})
        ], ignore_index=True)

# Step 8: Sort quarters chronologically
correct_sentiment_pct = correct_sentiment_pct.sort_values(by='Quarter')

# Step 9: Plot chart
plt.figure(figsize=(8, 5))
bars = plt.bar(
    correct_sentiment_pct['Quarter'],
    correct_sentiment_pct['Correct Sentiment %'],
    color='seagreen',
    edgecolor='black'
)

# Annotate bars with %
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1, f'{height:.1f}%', ha='center', va='bottom')

plt.title('Correct Sentiment Alignment by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Correct Sentiment %')
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Articles with Correct Sentiment Matching EPS Surprise:
#
# Quarter                                                                                            Headline                                                       Authors Sentiment EPS_Sentiment
# Q2 2025                                                Apple iPad Air M3 review: the premium tablet to beat                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q2 2025                                                   Apple launches iPhone 16e and ditches home button                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q2 2025                                        Apple MacBook Air M4 review: the laptop to beat, now cheaper                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q2 2025                Apple quarterly earnings beat Wall Street expectations amid Trump trade policy chaos                                                     Dara Kerr  Positive      Positive
# Q2 2025                                       Apple announces $500bn in US investments over next four years                                   Johana Bhuiyan and agencies  Positive      Positive
# Q2 2025                        Apple ‘aims to source all US iPhones from India’, reducing reliance on China                            Dan Milmo Global technology editor  Positive      Positive
# Q2 2025                             Apple said to be flying iPhones from India to US to avoid Trump tariffs                            Dan Milmo Global technology editor  Positive      Positive
# Q2 2025                       Beats Powerbeats Pro 2 review: Apple’s best workout buds are back with a bang                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q2 2025                                Nvidia will spend hundreds of billions on US manufacturing, says CEO                                            Kalyeena Makortoff  Positive      Positive
# Q2 2025                                      TikTok ban deadline looms in US amid last-minute takeover bids                                                     Dara Kerr  Positive      Positive
# Q2 2025                           Crypto and big tech’s backing pays off as Trump makes tech-friendly moves                                  Dara Kerr and Johana Bhuiyan  Positive      Positive
# Q1 2025                                             Apple MacBook Pro M4 review: faster, better and cheaper                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q1 2025                               Apple Watch Series 10 review: thinner, lighter and basically the same                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q1 2025                                Silicon Valley’s right wing notches victories nationwide and at home                                                Johana Bhuiyan  Positive      Positive
# Q4 2024                                        Apple reveals iPhone 16 and ‘Apple Intelligence’ AI features                                             Nick Robins-Early  Positive      Positive
# Q4 2024                                      New iMessage feature allows children to report nudity to Apple                                                   Josh Taylor  Positive      Positive
# Q4 2024                                     Apple AirPods 4 review: better sound, now with noise cancelling                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q4 2024                                       iPhone 16 Pro review: Apple levels up its smaller ‘pro’ phone                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q4 2024                                   Apple iPad mini A17 Pro review: the best small tablet gets faster                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q4 2024                       Apple reports robust demand for iPhone 16 even as overall sales in China slow                                                Johana Bhuiyan  Positive      Positive
# Q4 2024                                  Apple Intelligence is coming. Here’s what it means for your iPhone                                               Kate O'Flaherty  Positive      Positive
# Q4 2024                                                        iPhone 16 Plus review: Apple’s battery beast                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q4 2024                                 iPhone 16 review: more buttons and speed for Apple’s standard phone                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q4 2024                               iOS 18 release: everything you need to know about Apple’s big updates                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q4 2024                                           OpenAI planning to become for-profit company, say reports                            Dan Milmo Global technology editor  Positive      Positive
# Q4 2024                                        Nvidia shares fall on slowing growth and production concerns                                            Kalyeena Makortoff  Positive      Positive
# Q3 2024                         Apple brings ChatGPT to Siri as it debuts ‘Apple Intelligence’ at WWDC 2024 Kari Paul in Cupertino and Nick Robins-Early in New York City  Positive      Positive
# Q3 2024                                       Apple beats earnings forecast despite decline in iPhone sales                                                     Kari Paul  Positive      Positive
# Q3 2024                                      Apple push into AI could spark smartphone upgrade ‘supercycle’                                   Alex Hern Technology editor  Positive      Positive
# Q3 2024                                    Beats Solo 4 review: Apple headphones get Android-loving upgrade                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q3 2024                        How Apple plans to usher in ‘new privacy standards’ with its long-awaited AI                                                     Kari Paul  Positive      Positive
# Q3 2024                                                 Beats Solo Buds review: Apple’s budget earbuds rock                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q3 2024                                           Nvidia becomes world’s most valuable company amid AI boom                                Nick Robins-Early and agencies  Positive      Positive
# Q3 2024               Apple’s Vision Pro headset is impressive – but it’s hard to know its ultimate purpose                                                   Josh Taylor  Positive      Positive
# Q3 2024 Australia’s eSafety commissioner waters down child abuse detection rules in online safety standards                                                   Josh Taylor  Positive      Positive
# Q3 2024                                     iPad Air M2 review: cheaper iPad Pro for rest of us gets bigger                       Samuel Gibbs Consumer technology editor  Positive      Positive
# Q3 2024                          OpenAI’s new GPT-4o model offers promise of improved smartphone assistants                                Alex Hern UK technology editor  Positive      Positive
# Q3 2024                            Nvidia reports stratospheric growth as AI boom shows no sign of stopping                                                Edward Helmore  Positive      Positive
# Q3 2024                     Meta accused of breaking EU digital law by charging for ad-free social networks                            Dan Milmo Global technology editor  Positive      Positive
# Q3 2024                                   X changes porn policy to opt-in system that blocks under-18 users                                                   Josh Taylor  Positive      Positive
