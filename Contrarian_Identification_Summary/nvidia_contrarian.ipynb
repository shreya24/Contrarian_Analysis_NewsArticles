# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load Excel file and read all sheets
file_path = "Nvidia_with_sentiment.xlsx"  # Update as needed
xls = pd.ExcelFile(file_path)
sheet_names = xls.sheet_names

# Step 2: Combine sheets into a single DataFrame, labeling by quarter
combined_df = pd.concat(
    [xls.parse(sheet).assign(Quarter=sheet) for sheet in sheet_names],
    ignore_index=True
)

# Step 3: Define true EPS sentiment direction for each quarter
eps_sentiment = {
    'Q2 2025': 'Positive',   # EPS Surprise: 9.19%
    'Q1 2025': 'Positive',   # EPS Surprise: 4.95%
    'Q4 2024': 'Positive',   # EPS Surprise: 8%
    'Q3 2024': 'Positive'    # EPS Surprise: 6.25%
}

# Step 4: Tag articles with sentiment alignment
combined_df['Sentiment'] = combined_df['Sentiment'].fillna('Neutral')
combined_df['EPS_Sentiment'] = combined_df['Quarter'].map(eps_sentiment)
combined_df['Sentiment_Alignment'] = combined_df['Sentiment'] == combined_df['EPS_Sentiment']

# Step 5: Filter only correctly aligned articles
correct_df = combined_df[combined_df['Sentiment_Alignment']][
    ['Quarter', 'Headline', 'Authors', 'Sentiment', 'EPS_Sentiment']
]

print("Articles with Correct Sentiment Matching EPS Surprise:\n")
print(correct_df.to_string(index=False))

# Step 6: Compute percentage of correctly aligned sentiment per quarter
correct_sentiment_pct = (
    combined_df.groupby('Quarter')['Sentiment_Alignment']
    .mean()
    .reset_index()
    .rename(columns={'Sentiment_Alignment': 'Correct Sentiment %'})
)
correct_sentiment_pct['Correct Sentiment %'] *= 100

# Step 7: Ensure all quarters in EPS list are present
for q in eps_sentiment:
    if q not in correct_sentiment_pct['Quarter'].values:
        correct_sentiment_pct = pd.concat([
            correct_sentiment_pct,
            pd.DataFrame({'Quarter': [q], 'Correct Sentiment %': [0]})
        ], ignore_index=True)

# Step 8: Sort quarters chronologically
correct_sentiment_pct = correct_sentiment_pct.sort_values(by='Quarter')

# Step 9: Plot chart
plt.figure(figsize=(8, 5))
bars = plt.bar(
    correct_sentiment_pct['Quarter'],
    correct_sentiment_pct['Correct Sentiment %'],
    color='seagreen',
    edgecolor='black'
)

# Annotate bars with %
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 1, f'{height:.1f}%', ha='center', va='bottom')

plt.title('Correct Sentiment Alignment by Quarter')
plt.xlabel('Quarter')
plt.ylabel('Correct Sentiment %')
plt.ylim(0, 100)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Articles with Correct Sentiment Matching EPS Surprise:
#
# Quarter                                                                                                 Headline                                                                                                    Authors Sentiment EPS_Sentiment
# Q2 2025                               Nvidia beats Wall Street expectations even as Trump tamps down China sales                                                                                             Johana Bhuiyan  Positive      Positive
# Q2 2025                                     Nvidia will spend hundreds of billions on US manufacturing, says CEO                                                                                         Kalyeena Makortoff  Positive      Positive
# Q2 2025               The Thinking Machine: Jensen Huang, Nvidia and the World’s Most Coveted microchip – review                                                                                              John Naughton  Positive      Positive
# Q2 2025                                US stock markets expected to recover after Trump drops tariffs on mobiles                                                                                              Phillip Inman  Positive      Positive
# Q2 2025                                                    From spit to bankruptcy: the rise and fall of 23andMe                                                                                           Blake Montgomery  Positive      Positive
# Q2 2025                         How Donald Trump’s ‘historic’ Gulf state deals benefit a handful of powerful men                                                                                           Blake Montgomery  Positive      Positive
# Q2 2025                                     Trump the AI salesman makes deals in the Gulf – and rich men benefit                                                                                           Blake Montgomery  Positive      Positive
# Q2 2025                                   Trump’s tech tariffs are total chaos – and everyone’s paying the price                                                                                           Blake Montgomery  Positive      Positive
# Q2 2025                     Trump hints at tariff reprieve for pharma companies that bring operations back to US                                                                        Lisa O'Carroll Senior correspondent  Positive      Positive
# Q2 2025                                                 Trump indicates ‘positive’ progress in US-EU trade talks                                                                                             Lisa O'Carroll  Positive      Positive
# Q2 2025                                          Trump agrees deal for UAE to build largest AI campus outside US                                                                                Guardian staff and agencies  Positive      Positive
# Q2 2025     Trump news at a glance: president gives Syria ‘chance at greatness’ with promise of sanctions relief                                                                                             Guardian staff  Positive      Positive
# Q2 2025                                     Trump pauses plans to hike US tariffs on most countries except China Callum Jones in New York, Jennifer Rankin in Brussels, Helen Davidson in Taipei and Rowena Mason in London  Positive      Positive
# Q1 2025                        Nvidia beats Wall Street expectations in first earnings after DeepSeek’s AI debut                                                                                             Johana Bhuiyan  Positive      Positive
# Q1 2025                                             Arm looks to launch its own chip after landing Meta contract                                                                                                Rachel Hall  Positive      Positive
# Q1 2025                                    The stock market is always terrible at valuing technology revolutions                                                                                               Nils Pratley  Positive      Positive
# Q1 2025                     US tech stocks partly recover after Trump says DeepSeek AI chatbot is ‘wake-up call’                                                                                                Mark Sweney  Positive      Positive
# Q1 2025                                         A year of two halves: how global financial markets fared in 2024                                                                                             Graeme Wearden  Positive      Positive
# Q1 2025                                AI ‘godfather’ predicts another revolution in the tech in next five years                                                                         Dan Milmo Global technology editor  Positive      Positive
# Q1 2025                          Microsoft reports strong fourth-quarter earnings amid uproar over DeepSeek’s AI                                                                                             Edward Helmore  Positive      Positive
# Q1 2025                                       The most important tech stories of 2024, and also my favorite ones                                                                                           Blake Montgomery  Positive      Positive
# Q4 2024                                Nvidia earnings: AI chip leader shows no signs of stopping mammoth growth                                                                                             Edward Helmore  Positive      Positive
# Q4 2024                        Nvidia rides big tech’s AI investment to beat Wall Street’s sky-high expectations                                                                                             Edward Helmore  Positive      Positive
# Q4 2024                  ‘Invent the future’: one man’s dream of making upstate New York the next Silicon Valley                                                                           Edward Helmore in Troy, New York  Positive      Positive
# Q4 2024                                                     OpenAI raises $6.6bn in funding, is valued at $157bn                                                                         Dan Milmo Global technology editor  Positive      Positive
# Q4 2024                                   Microsoft sails as AI boom fuels double-digit growth in cloud business                                                                                             Edward Helmore  Positive      Positive
# Q4 2024                                               What a second Trump presidency means for big US tech firms                                                                         Robert Booth  UK technology editor  Positive      Positive
# Q4 2024 ‘You don’t want to waste time on climate change’: TV weather’s big problem with the environmental crisis                                                                                            Stuart Jeffries  Positive      Positive
# Q3 2024                        Nvidia rides big tech’s AI investment to beat Wall Street’s sky-high expectations                                                                                             Edward Helmore  Positive      Positive
# Q3 2024                                                Nvidia becomes world’s most valuable company amid AI boom                                                                             Nick Robins-Early and agencies  Positive      Positive
# Q3 2024                                     Can AI boom drive Nvidia to a $4tn valuation despite investor doubt?                                                                                    Dan Milmo and Alex Hern  Positive      Positive
# Q3 2024                                       Mixed signals on tech stocks amid debate over viability of AI boom                                                                        Kalyeena Makortoff and Jasper Jolly  Positive      Positive
# Q3 2024                  ‘Invent the future’: one man’s dream of making upstate New York the next Silicon Valley                                                                           Edward Helmore in Troy, New York  Positive      Positive
# Q3 2024                                  UK risks tech ‘talent drain’ to US if pension funds fail to back sector                                                                         Dan Milmo Global technology editor  Positive      Positive
# Q3 2024                                    Nasdaq losses deepen amid market jitters over US policy on chipmakers                                                                                 Dan Milmo and Jack Simpson  Positive      Positive
# Q3 2024                                  Hyundai to double hybrid range as demand for ‘pure’ electric cars slows                                                                                                Mark Sweney  Positive      Positive
# Q3 2024                                UK winemaker Chapel Down considers raising cash or sale as trade sparkles                                                                                              Julia Kollewe  Positive      Positive
# Q3 2024                            Australian share market bounces back to ease immediate concerns over meltdown                                                                  Jonathan Barrett Senior business reporter  Positive      Positive
# Q3 2024                                                 Currys looks to AI tech to drive growth as profits climb                                                                                              Julia Kollewe  Positive      Positive
# Q3 2024         First Thing: Dozens killed in Israeli strike on UN school as IDF launches central Gaza operation                                                                                            Jem Bartholomew  Positive      Positive
# Q3 2024                                 How Taiwan secured semiconductor supremacy – and why it won’t give it up                                                                   Helen Davidson and Chi-hui Lin in Taipei  Positive      Positive
