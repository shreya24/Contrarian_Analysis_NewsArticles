# %%
from getpass import getpass

a = getpass("Enter password")
print(a)
# Out:
# tuks

# %%
class RanchiPerson: 
    stupidbutt = 100

    @staticmethod
    def are_stupid():
        # if self.age > 5: # Can't write this. Why? Because self is never passed in to static methods. 
        #                  # This is "instance agnostic", or in simple words, only dependent on the class, not a specific object of the class.
        #     return True
        return True

    def __init__(self, name):
        self.name = name

    def loving_wife(self):
        return True
    
    def are_intelligent(self):
        return True
    
    def has_friends(self) -> bool:
        if self.name == "Tuks": return False
        elif not self.name == "Tuks": return True

    def school_attended(self):
        if not self.name == "stupid people": return "Other good schools"
        else: return "dps"

tuku = RanchiPerson("tuku")
print(tuku.loving_wife())
print(tuku.stupidbutt)
print(tuku.loving_wife())
print(tuku.stupidbutt)
print(tuku.are_stupid())

shivam = RanchiPerson("shivam")
print(shivam.stupidbutt)
print(shivam.are_stupid())
# Out:
# True
# 100
# True
# 100
# True
# 100
# True
