# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=Apple&'
       'from=2025-04-20&'
       'sortBy=popularity&'
       'apiKey=aa97db5ece6a4d2093fceadcc9f0bf92')

response = requests.get(url)

# %%
from datetime import timedelta
import datetime
from os import environ
try:
    from newsapi.newsapi_client import NewsApiClient
except:
    # !pip3 install newsapi.newsapi_client

newsapi = NewsApiClient(api_key='ABC')
to_date = datetime.date.today() - timedelta(days = 1)
from_date = to_date - datetime.timedelta(days=28)

def filter_articles(articles: dict):
    filter_n_articles = articles['articles'][0:len(articles['articles'])]
    list_of_articles = []
    for article in filter_n_articles:
        if "\'" not in article['description'] and 'www.macrumors.com' not in article['url']: 
            a = {
                'source_name': article['source']['name'],
                'author': article['author'],
                'title': article['title'],
                'description': article['description'],
                'published': article['publishedAt'],
                'url': article['url']
            }
        else: continue
        list_of_articles.append(a)
    return list_of_articles


all_articles = newsapi.get_everything(q='apple',
                                       from_param = from_date,
                                       to = to_date,
                                       language = 'en',
                                       sort_by = 'relevancy')
filter_articles(all_articles)

# %%
all_articles = newsapi.get_everything(q='apple',
                                       from_param = from_date,
                                       to = to_date,
                                       language = 'en',
                                       sort_by = 'relevancy')
print(all_articles)
articles_list = []
filter_n_articles = all_articles['articles'][0:len(all_articles['articles'])]
for article in filter_n_articles:
    if "\'" not in article['description'] and 'www.macrumors.com' not in article['url']:
        articles_list.append(article)

print(len(articles_list))

# %%
import pandas as pd

filtered_articles = filter_articles(all_articles)
df_articles = pd.DataFrame(filtered_articles)
# df_articles.to_excel('apple_articles.xlsx', index=False)

# print("Saved!")

# %%
import asyncio
from crawl4ai import *

async def extract_Article_body(url, baseSelector, selector):
    browser_config = BrowserConfig(
        browser_type="chromium",  # Options: "chromium", "firefox", "webkit"
        headless=True,            # Set to False if you want to see the browser window
        viewport_width=1280,
        viewport_height=800,
        verbose=True,
        user_agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
    )
    async with AsyncWebCrawler(config = browser_config) as crawler:

        json_strategy = JsonCssExtractionStrategy(
        schema = {
            "name": "Article Body",
            "baseSelector": baseSelector,
            "fields" : [
                {
                "name": "Section",
                # "selector": selector,
                "type": "text"
                }
            ]
                },
        verbose = False
        )

        crawler_config = CrawlerRunConfig(
            extraction_strategy = json_strategy,
            screenshot=False,
            verbose=True,
            cache_mode=CacheMode.DISABLED,
            log_console=True,
            # wait_for=".swiper-slide-body",
            scan_full_page=True,  # Tells the crawler to try scrolling the entire page
            scroll_delay=2,     # Delay (seconds) between scroll steps
        )

        result = await crawler.arun(
            url = url, 
            config = crawler_config
        )
        # print(result.markdown)
        return result.extracted_content

# %%
async def process_each_article(wired_articles):
    extracted_content_list = []
    for each_url in wired_articles["url"]:
        extracted_content = await extract_Article_body(each_url, "#main-content > article > div.ArticlePageContentBackGround-cNiFNN.lkiVTY.article-body__content > div.ArticlePageChunksContent-etcMtP.bwyLBj > div.ArticlePageChunks-fLyCVG.eOdfIs", "#main-content > article > div.ArticlePageContentBackGround-cNiFNN.lkiVTY.article-body__content > div.ArticlePageChunksContent-etcMtP.bwyLBj > div.ArticlePageChunks-fLyCVG.eOdfIs > div:nth-child(1) > div.GridItem-buujkM.stRKV.grid--item.grid-layout__content")
        # if not extracted_content:
            # extracted_content = await extract_Article_body(each_url, "#content > article > div.duet--layout--entry-body-container._1t5ltw90._1ymtmqp3._1ymtmqp13 > div", "#zephr-anchor")
        extracted_content_list.append(extracted_content)
    return extracted_content_list

if __name__ == "__main__":
    df_articles = pd.DataFrame(filtered_articles)
    wired_articles = df_articles[df_articles["source_name"] == "Wired"]
    extracted_content_list = await process_each_article(wired_articles)
    print(extracted_content_list)
# Out:
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: a: 0.003173828125 ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 184ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0 ms
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 266ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 420ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 8ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: NotSupportedError: The element has no supported sources.
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_HTTP2_PROTOCOL_ERROR
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 211ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 468ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 161ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 7ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_CONNECTION_REFUSED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [FETCH]... ↓ https://www.wired.com/story/apple-watch-turns-10/                                                    |
# ✓ | ⏱: 56.81s
# [SCRAPE].. ◆ https://www.wired.com/story/apple-watch-turns-10/                                                    |
# ✓ | ⏱: 0.18s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/apple-watch-turns-10/... | Time: 0.048798540999996476s
# [COMPLETE] ● https://www.wired.com/story/apple-watch-turns-10/                                                    |
# ✓ | ⏱: 57.05s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console error: Cannot destructure property 'nodeName' of 'e' as it is null.
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: [[Meta Pixel]] - Removed parameters from custom data due to potential violations. Go to
# Events Manager to learn more.
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: Powered by AMP ⚡ HTML – Version 2504241805000
# https://www.wired.com/gallery/best-macbook-accessories/
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.00390625 ms
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 231ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.0009765625 ms
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 199ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 306ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 21ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 572ms
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 185ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 169ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 8ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 273ms
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 75ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 214ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 2ms
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Access to fetch at 'https://hbopenbid.pubmatic.com/translator?source=prebid-client' from
# origin 'https://www.wired.com' has been blocked by CORS policy: No 'Access-Control-Allow-Origin' header is present
# on the requested resource.
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_FAILED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_CONNECTION_REFUSED
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 435ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 358ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 167ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 32ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 183ms
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 478ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 276ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 4ms
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 261ms
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 200ms
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 160ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 8ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 333ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 991ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 404ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 13ms
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 232ms
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_CONNECTION_REFUSED
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 283ms
# [CONSOLE]. ℹ Console: This ad's html cannot be accessed using the getHtml method on googletag.Slot. Returning the
# empty string instead.
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 243ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 38ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [FETCH]... ↓ https://www.wired.com/gallery/best-macbook-accessories/                                              |
# ✓ | ⏱: 104.15s
# [SCRAPE].. ◆ https://www.wired.com/gallery/best-macbook-accessories/                                              |
# ✓ | ⏱: 0.32s
# [EXTRACT]. ■ Completed for https://www.wired.com/gallery/best-macbook-accesso... | Time: 0.12515912500020931s
# [COMPLETE] ● https://www.wired.com/gallery/best-macbook-accessories/                                              |
# ✓ | ⏱: 104.68s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.0009765625 ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.003173828125 ms
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 471ms
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: NotSupportedError: Failed to load because no supported source was found.
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 524ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 157ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 9ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 189ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 289ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x633` took 48ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x633` took 5ms
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [FETCH]... ↓ https://www.wired.com/story/how-to-use-apple-maps-on-the-web/                                        |
# ✓ | ⏱: 35.92s
# [SCRAPE].. ◆ https://www.wired.com/story/how-to-use-apple-maps-on-the-web/                                        |
# ✓ | ⏱: 0.13s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/how-to-use-apple-maps-... | Time: 0.03525470900058281s
# [COMPLETE] ● https://www.wired.com/story/how-to-use-apple-maps-on-the-web/                                        |
# ✓ | ⏱: 36.09s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.0029296875 ms
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.00390625 ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0 ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 494ms
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 324ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 1432ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 17ms
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [FETCH]... ↓ https://www.wired.com/story/apple-juice-shortage-tariffs/                                            |
# ✓ | ⏱: 31.88s
# [SCRAPE].. ◆ https://www.wired.com/story/apple-juice-shortage-tariffs/                                            |
# ✓ | ⏱: 0.19s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/apple-juice-shortage-t... | Time: 0.3938136670003587s
# [COMPLETE] ● https://www.wired.com/story/apple-juice-shortage-tariffs/                                            |
# ✓ | ⏱: 32.50s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: a: 0.00390625 ms
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.00390625 ms
# [CONSOLE]. ℹ Console: Metrics: `ad-content-load` took 285ms
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Metrics: `flowline-load` took 568ms
# [CONSOLE]. ℹ Console: Metrics: `asset-load-1280x346` took 365ms
# [CONSOLE]. ℹ Console: Metrics: `ad-render-1280x346` took 20ms
# [CONSOLE]. ℹ Console error: Failed to execute 'postMessage' on 'Window': Invalid target origin 'null' in a call to
# 'postMessage'.
# [CONSOLE]. ℹ Console error: Failed to execute 'postMessage' on 'Window': Invalid target origin 'null' in a call to
# 'postMessage'.
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console error: The element has no supported sources.
# [FETCH]... ↓ https://www.wired.com/story/antitrust-judge-asks-doj-prosecute-apple/                                |
# ✓ | ⏱: 28.37s
# [SCRAPE].. ◆ https://www.wired.com/story/antitrust-judge-asks-doj-prosecute-apple/                                |
# ✓ | ⏱: 0.12s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/antitrust-judge-asks-d... | Time: 0.043819250000524335s
# [COMPLETE] ● https://www.wired.com/story/antitrust-judge-asks-doj-prosecute-apple/                                |
# ✓ | ⏱: 28.55s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_SOCKET_NOT_CONNECTED
# [CONSOLE]. ℹ Console: a: 0.0029296875 ms
# ...
# {_isId5Message: true, id: 133, timestamp: 1747938815039, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.077Z Instance(id=a639c1bd-f26a-4691-889a-0b06b0e9e88d, role=follower) Message received
# {_isId5Message: true, id: 134, timestamp: 1747938815040, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.077Z Instance(id=4ceb89f4-700d-44e6-9916-e141acdcb043, role=follower) Message received
# {_isId5Message: true, id: 135, timestamp: 1747938815041, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.078Z Instance(id=451faa6d-81db-4dd6-a82c-b03ed6a5d901, role=follower) Message received
# {_isId5Message: true, id: 136, timestamp: 1747938815042, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.078Z Instance(id=43d37f92-f0dc-4b56-b78c-dc9f5cbf3ae0, role=follower) Message received
# {_isId5Message: true, id: 137, timestamp: 1747938815043, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; INFO
# 2025-05-22T18:33:35.079Z Id5Instance: User id updated {hasChanged: true, fromCache: false}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.079Z Instance(id=6888a767-00c6-48f2-aee3-0f6fd2fd23e1, role=follower) Message received
# {_isId5Message: true, id: 138, timestamp: 1747938815044, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; INFO
# 2025-05-22T18:33:35.079Z Id5Instance: User id updated {hasChanged: true, fromCache: false}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.080Z Instance(id=a639c1bd-f26a-4691-889a-0b06b0e9e88d, role=follower) Message received
# {_isId5Message: true, id: 139, timestamp: 1747938815046, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; INFO
# 2025-05-22T18:33:35.081Z Id5Instance: User id updated {hasChanged: true, fromCache: false}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.081Z Instance(id=4ceb89f4-700d-44e6-9916-e141acdcb043, role=follower) Message received
# {_isId5Message: true, id: 140, timestamp: 1747938815047, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; INFO
# 2025-05-22T18:33:35.081Z Id5Instance: User id updated {hasChanged: true, fromCache: false}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.082Z Instance(id=451faa6d-81db-4dd6-a82c-b03ed6a5d901, role=follower) Message received
# {_isId5Message: true, id: 141, timestamp: 1747938815048, type: RemoteMethodCallMessage, src:
# 2540945f-4b65-482f-973c-044e5640b798}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; INFO
# 2025-05-22T18:33:35.082Z Id5Instance: User id updated {hasChanged: true, fromCache: false}
# [CONSOLE]. ℹ Console: %cID5 - api#1 color: #fff; background: #1c307e; padding: 1px 4px; border-radius: 3px; DEBUG
# 2025-05-22T18:33:35.083Z Id5Instance: Firing onAvailable callback after 487ms. Triggered by eventOccurred,
# configured timeoutMs=undefined
# [FETCH]... ↓ https://www.wired.com/story/sam-altman-orb-eyeball-scan-launch-us/                                   |
# ✓ | ⏱: 39.60s
# [SCRAPE].. ◆ https://www.wired.com/story/sam-altman-orb-eyeball-scan-launch-us/                                   |
# ✓ | ⏱: 0.12s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/sam-altman-orb-eyeball... | Time: 0.041275499999755993s
# [COMPLETE] ● https://www.wired.com/story/sam-altman-orb-eyeball-scan-launch-us/                                   |
# ✓ | ⏱: 39.77s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #418; visit
# https://reactjs.org/docs/error-decoder.html?invariant=418 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console error: Minified React error #423; visit
# https://reactjs.org/docs/error-decoder.html?invariant=423 for the full message or use the non-minified dev
# environment for full errors and additional helpful warnings.
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.005126953125 ms
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console error: object is not iterable (cannot read property Symbol(Symbol.iterator))
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: %c----------------------------------------
# ------------- 15 SECONDS ---------------
# ----------------------------------------
#  background: #ffff33; color: #ff00ff
# [FETCH]... ↓ https://www.wired.com/story/jony-ive-open-ai-hardware-io/                                            |
# ✓ | ⏱: 28.42s
# [SCRAPE].. ◆ https://www.wired.com/story/jony-ive-open-ai-hardware-io/                                            |
# ✓ | ⏱: 0.20s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/jony-ive-open-ai-hardw... | Time: 0.2048787089988764s
# [COMPLETE] ● https://www.wired.com/story/jony-ive-open-ai-hardware-io/                                            |
# ✓ | ⏱: 28.88s
# [INIT].... → Crawl4AI 0.6.3
# [CONSOLE]. ℹ Console: Subscriptions Runtime: 1.0.106
# [CONSOLE]. ℹ Console error: No config could be discovered in the page
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-method"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "access-control-request-headers"
# [CONSOLE]. ℹ Console: Refused to set unsafe header "user-agent"
# [CONSOLE]. ℹ Console: Failed to create WebGPU Context Provider
# [CONSOLE]. ℹ Console:
# [CONSOLE]. ℹ Console: Allow attribute will take precedence over 'allowfullscreen'.
# [CONSOLE]. ℹ Console: [[Audigent]] script has already been initialised. Skip further execution
# [CONSOLE]. ℹ Console: VIDEOJS: ERROR: (CODE:4 MEDIA_ERR_SRC_NOT_SUPPORTED) The media could not be loaded, either
# because the server or network failed or because the format is not supported. It
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: Error
# [CONSOLE]. ℹ Console: a: 0.0048828125 ms
# [CONSOLE]. ℹ Console: a: 0.033935546875 ms
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_NAME_NOT_RESOLVED
# [CONSOLE]. ℹ Console: Error while reading nspb data from sharedStorage OperationError:
# sharedStorage.worklet.addModule is disabled because either sharedStorage is disabled or both
# sharedStorage.selectURL and privateAggregation are disabled
# [CONSOLE]. ℹ Console: Failed to load resource: the server responded with a status of 502 ()
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [CONSOLE]. ℹ Console: Failed to load resource: net::ERR_CONNECTION_REFUSED
# [CONSOLE]. ℹ Console: updateCorrelator has been deprecated. Please see the Google Ad Manager help page on
# "Pageviews in GPT" for more information: https://support.google.com/admanager/answer/183281?hl=en
# [CONSOLE]. ℹ Console: [[GPT]] updateCorrelator has been deprecated. See the Google Ad Manager help page on
# "Creative selection for multiple ad slots" for more information:
# https://support.google.com/admanager/answer/183281.
# https://goo.gle/gpt-message#115
# [FETCH]... ↓ https://www.wired.com/story/airbnb-is-in-midlife-crisis-mode-reinvention-app-services/               |
# ✓ | ⏱: 65.17s
# [SCRAPE].. ◆ https://www.wired.com/story/airbnb-is-in-midlife-crisis-mode-reinvention-app-services/               |
# ✓ | ⏱: 0.12s
# [EXTRACT]. ■ Completed for https://www.wired.com/story/airbnb-is-in-midlife-c... | Time: 0.032456499997351784s
# [COMPLETE] ● https://www.wired.com/story/airbnb-is-in-midlife-crisis-mode-reinvention-app-services/               |
# ✓ | ⏱: 65.33s
# ['[\n    {\n        "Section": "It’s been 10years since theApple Watchdebuted. It was actually announced at a special event on September 9, 2014, but only became available to buy seven months later, on April 24, 2025.While it seems hard now to recall a time when the Apple Watch, or something similar, did not exist, the market hasn\'t always been so obvious. It was only 10 years ago that we were still wondering if Pebble would actuallypan out, and all anyone wanted a Fitbit for was to get in their 10,000 steps (an entirely arbitrary number, but I digress).AdChoicesADVERTISEMENTCustomers in Sydney, Australia, queueing for a look at the first Apple Watch in April 2015.Photograph: Bloomberg/Getty ImagesWhen it debuted, the first Apple Watch wasglitchy and expensive.Battery life sucked. Many publications, including mine, spent significant time and space wondering why anyone evenwanteda smartwatch. Today, it is an Apple success story. “Since 2015 til the end of 2024, we estimate that 281.2 million Apple watches have been shipped,” Jitesh Ubrani, a device research manager at IDC, tells WIRED. That\'s at an estimated value of $127 billion. No wonder it has spawned aflotilla of imitators.Featured VideoHowever, on its 10th anniversary (or perhaps more appropriately its aluminum anniversary), the Apple WatchSeries 10faces a tumultuous global market. Even before theTrump administration announced tariffs, globalsmartwatch sales were slumping. As innovation slows (or is blocked inpatent disputes), people are nowholding on to their Apple devices for longer,while newer smartwatches, such as theGalaxy Watchare also coming for Apple’s lunch.Gear Newsletter: Reviews, Guides, and DealsUpgrade your life with our buying guides, deals, and how-to guides, all tested by experts.Sign upBy signing up, you agree to ouruser agreement(includingclass action waiver and arbitration provisions), and acknowledge ourprivacy policy.Sleeping BeautyCheckReddit’s r/AppleWatchand you’ll find people who still own—and use—the original Series 0. It’s a reminder that Apple’sJony Ivepouredyears of workinto a tiny design that was originally intended to be a piece of jewelry, before reportedly clashing with executives over what the watch’s eventual function would be.Potential buyers look at the various options offered by the first Apple Watch.Photograph: Bloomberg/Getty ImagesMost PopularGear News and EventsEverything Google Announced at I/O 2025ByBoone AshworthSpeakersMarshall Takes On Sonos With Its First SoundbarByVerity BurnsGear News and EventsWith AI Mode, Google Search Is About to Get Even ChattierByReece RogersGear News and EventsGoogle’s Android Chief Hopes Its ‘New Era’ Will Get People to Ditch Their iPhonesByJulian ChokkattuAdvertisementInitial unfortunate nomenclature aside—Tim Cook casually called it “the iWatch”, before that horrible namewas kibosheddue to patent squabbles—it was beguiling, and Ive had his wish. Walking into an Apple Store and picking out your case and accessories was the closest many might have come to a luxury watch purchasing experience.Because the Watch is not just a simple timepiece—you can change it to suit your needs or mood. When you buy an Apple Watch, you can alsopick or change your bands, from thenow-classic Milanese loopto the company’ssuccessful collaboration with Hermès. You canchange your watch faceto suit your outfit, to check if Snoopy has a cute new cartoon for the day, to go sailing, ormap your way back off the trail. Those two ingenious buttons on the case’s back that let you easily switch out your straps at a whim with no tools are now copied byalmostallmanufacturersin the watch industry, not just smartwatch manufacturers.“Apple showed that [the strap] was a critical part of the design language, but also laid down the gauntlet in engineering secure, easy-to-use quick-release systems that didn’t require tools. Brands have put a lot of R&D into this,” said Tim Barber,WIRED’s watch expert.Whilethe $10,000 Apple Watchwas certa ...

# %%
import json
from json import loads

wired_articles = wired_articles.reset_index(drop=True)
wired_articles_copied = wired_articles.copy()
extracted_content_listV2 = extracted_content_list.copy()
wired_articles_copied["article_body"] = "Empty"
for i in range(len(extracted_content_listV2)):
    json_article_content = loads(extracted_content_listV2[i])
    # wired_articles_copied["article_body"].loc[i] = json_article_content[0]["Section"]
    # print(i)
    if len(json_article_content) != 0:
        # print(i)
        wired_articles_copied.at[i, "article_body"] = json_article_content[0]["Section"]
    else:
        print("empty " + str(i))
        wired_articles_copied.at[i, "article_body"] = "Empty"

    # wired_articles_copied["article_body"].loc[i] = extracted_content_listV2[i][extracted_content_listV2[i].find(":"):-7]
# Out:
# empty 1
# empty 8

# %%
def split_text_into_chunks(text, max_words):
    words = text.split()
    return [' '.join(words[i:i + max_words]) for i in range(0, len(words), max_words)]

max_words = 5000

new_rows = []
for _, row in wired_articles_copied.iterrows():
    chunks = split_text_into_chunks(row['article_body'], max_words)
    new_row = row.to_dict()
    for i, chunk in enumerate(chunks):
        if i == 0:
            new_row['article_body'] = chunk
        else:
           new_row[f'article_body_part_{i}'] = chunk
    new_rows.append(new_row)

df_expanded = pd.DataFrame(new_rows)

# #Save to Excel
df_expanded.to_excel('apple_Wired_articles_with_body_2.xlsx', index=False)

print("Saved!")
# Out:
# Saved!
